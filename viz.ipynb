# %% [markdown]
# # Setup

# %%
import pickle
import pandas as pd
import pathlib
import matplotlib.pyplot as plt

with open("doc_urls.pickle", "rb") as f:
    doc_urls = pickle.load(f)

ASPECT_RATIO = (20, 10)

# %% [markdown]
# # Metro Viz

# %%
metros = ["Ann Arbor, MI", "Detroit, MI"]

for description, url in doc_urls.items():
    if url.split("/")[-1].startswith("Metro"):
        path = "./data/" + url
        # print(f'starting viz for path {path}')
        try:
            df = pd.read_csv(path)
            df = df[df.StateName == "MI"]
        except Exception as e:
            # print(f'failed to read {path}: {e}')
            continue
        try:
            select_df = df[df.RegionName.isin(metros)].set_index("RegionName")
        except AttributeError as e:
            # print(f'failed to select {path}: {e}')
            continue

        i = 0
        while True:
            try:
                fig = select_df.iloc[:, i:].T.plot(
                    figsize=ASPECT_RATIO,
                    xlabel="Date",
                    ylabel=description,
                    title=f"{description} in {metros}",
                )
                fig.get_figure().savefig(f"./viz/{url.split('/')[-1]}.png")
                fig.get_figure().clf()
                print(f"fig saved to: ./viz/{url.split('/')[-1]}.png")
                break
            except:
                i += 1
                if i > 10:
                    break
# Out:
# fig saved to: ./viz/Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_month.csv.png
# fig saved to: ./viz/Metro_zhvi_uc_sfrcondo_tier_0.67_1.0_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_zhvi_uc_sfrcondo_tier_0.0_0.33_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_zhvi_uc_sfr_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_zhvi_uc_condo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_zhvi_bdrmcnt_1_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_zhvi_bdrmcnt_2_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_zhvi_bdrmcnt_3_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_zhvi_bdrmcnt_4_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_zhvi_bdrmcnt_5_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_zhvf_growth_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_zori_uc_sfrcondomfr_sm_month.csv.png
# fig saved to: ./viz/Metro_zori_uc_sfrcondomfr_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_zori_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/Metro_zori_uc_sfr_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_zori_uc_mfr_sm_month.csv.png
# fig saved to: ./viz/Metro_zori_uc_mfr_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_zordi_uc_sfrcondomfr_month.csv.png
# fig saved to: ./viz/Metro_zordi_uc_sfr_month.csv.png
# /home/user/.local/lib/python3.14/site-packages/pandas/plotting/_matplotlib/core.py:599: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=self.figsize)
# fig saved to: ./viz/Metro_zordi_uc_condo_month.csv.png
# fig saved to: ./viz/Metro_zordi_uc_mfr_month.csv.png
# fig saved to: ./viz/Metro_invt_fs_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_invt_fs_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_invt_fs_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/Metro_invt_fs_uc_sfr_sm_week.csv.png
# fig saved to: ./viz/Metro_invt_fs_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_invt_fs_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_invt_fs_uc_sfr_month.csv.png
# fig saved to: ./viz/Metro_invt_fs_uc_sfr_week.csv.png
# fig saved to: ./viz/Metro_new_listings_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_new_listings_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_new_listings_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_new_listings_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_new_pending_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_new_pending_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_new_pending_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_new_pending_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_mlp_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_mlp_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_mlp_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/Metro_mlp_uc_sfr_sm_week.csv.png
# fig saved to: ./viz/Metro_mlp_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_mlp_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_mlp_uc_sfr_month.csv.png
# fig saved to: ./viz/Metro_mlp_uc_sfr_week.csv.png
# fig saved to: ./viz/Metro_sales_count_now_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_median_sale_price_uc_sfrcondo_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_median_sale_price_uc_sfrcondo_sm_sa_week.csv.png
# fig saved to: ./viz/Metro_median_sale_price_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_median_sale_price_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_median_sale_price_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_median_sale_price_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_median_sale_price_uc_sfr_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_median_sale_price_uc_sfr_sm_sa_week.csv.png
# fig saved to: ./viz/Metro_median_sale_price_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/Metro_median_sale_price_uc_sfr_sm_week.csv.png
# fig saved to: ./viz/Metro_median_sale_price_uc_sfr_month.csv.png
# fig saved to: ./viz/Metro_median_sale_price_uc_sfr_week.csv.png
# fig saved to: ./viz/Metro_mean_sale_to_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_mean_sale_to_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_mean_sale_to_list_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_mean_sale_to_list_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_median_sale_to_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_median_sale_to_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_median_sale_to_list_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_median_sale_to_list_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_pct_sold_above_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_pct_sold_above_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_pct_sold_above_list_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_pct_sold_above_list_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_pct_sold_below_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_pct_sold_below_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_pct_sold_below_list_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_pct_sold_below_list_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_mean_sale_price_uc_sfrcondo_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_mean_sale_price_uc_sfrcondo_sm_sa_week.csv.png
# fig saved to: ./viz/Metro_mean_sale_price_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_mean_sale_price_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_mean_sale_price_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_mean_sale_price_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_mean_sale_price_uc_sfr_week.csv.png
# fig saved to: ./viz/Metro_total_transaction_value_uc_sfrcondo_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_total_transaction_value_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_total_transaction_value_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_total_transaction_value_uc_sfr_sm_sa_month.csv.png
# fig saved to: ./viz/Metro_total_transaction_value_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/Metro_total_transaction_value_uc_sfr_month.csv.png
# fig saved to: ./viz/Metro_mean_doz_pending_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_mean_doz_pending_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_mean_doz_pending_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_mean_doz_pending_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_med_doz_pending_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_med_doz_pending_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_med_doz_pending_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_med_doz_pending_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_mean_days_to_close_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_mean_days_to_close_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_mean_days_to_close_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_mean_days_to_close_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_median_days_to_close_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_median_days_to_close_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_median_days_to_close_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_median_days_to_close_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_perc_listings_price_cut_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_perc_listings_price_cut_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_perc_listings_price_cut_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_perc_listings_price_cut_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_perc_listings_price_cut_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/Metro_perc_listings_price_cut_uc_sfr_sm_week.csv.png
# fig saved to: ./viz/Metro_perc_listings_price_cut_uc_sfr_month.csv.png
# fig saved to: ./viz/Metro_perc_listings_price_cut_uc_sfr_week.csv.png
# fig saved to: ./viz/Metro_mean_listings_price_cut_amt_uc_sfr_month.csv.png
# fig saved to: ./viz/Metro_mean_listings_price_cut_amt_uc_sfr_week.csv.png
# fig saved to: ./viz/Metro_mean_listings_price_cut_amt_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/Metro_mean_listings_price_cut_amt_uc_sfr_sm_week.csv.png
# fig saved to: ./viz/Metro_mean_listings_price_cut_amt_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_mean_listings_price_cut_amt_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_mean_listings_price_cut_amt_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_mean_listings_price_cut_amt_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_mean_listings_price_cut_perc_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_mean_listings_price_cut_perc_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_mean_listings_price_cut_perc_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_mean_listings_price_cut_perc_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_med_listings_price_cut_amt_uc_sfr_month.csv.png
# fig saved to: ./viz/Metro_med_listings_price_cut_amt_uc_sfr_week.csv.png
# fig saved to: ./viz/Metro_med_listings_price_cut_amt_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/Metro_med_listings_price_cut_amt_uc_sfr_sm_week.csv.png
# fig saved to: ./viz/Metro_med_listings_price_cut_amt_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_med_listings_price_cut_amt_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_med_listings_price_cut_amt_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_med_listings_price_cut_amt_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_med_listings_price_cut_perc_uc_sfr_month.csv.png
# fig saved to: ./viz/Metro_med_listings_price_cut_perc_uc_sfr_week.csv.png
# fig saved to: ./viz/Metro_med_listings_price_cut_perc_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/Metro_med_listings_price_cut_perc_uc_sfr_sm_week.csv.png
# fig saved to: ./viz/Metro_med_listings_price_cut_perc_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_med_listings_price_cut_perc_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Metro_med_listings_price_cut_perc_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Metro_med_listings_price_cut_perc_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Metro_market_temp_index_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_new_con_sales_count_raw_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_new_con_median_sale_price_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_new_con_median_sale_price_per_sqft_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Metro_new_con_mean_sale_price_uc_sfrcondo_month.csv.png

# %% [markdown]
# # Zip Viz

# %% [markdown]
# https://zipmap.net/Michigan.htm
#
# ![zips](./zips.PNG)

# %%
zips = [
    48374,
    48375,
    48167,
    48335,
    48336,
    48167,
    48152,
    48240,
    48168,
    48154,
    48239,
    48170,
    48150,
]

for description, url in doc_urls.items():
    url = url.replace("Metro", "Zip")
    if url.split("/")[-1].startswith("Zip"):
        path = "./data/" + url
        # print(f'starting viz for path {path}')
        try:
            df = pd.read_csv(path)
            df = df[df.StateName == "MI"]
        except Exception as e:
            # print(f'failed to read {path}: {e}')
            continue
        try:
            select_df = df[df.RegionName.isin(zips)].set_index("RegionName")
        except AttributeError as e:
            # print(f'failed to select {path}: {e}')
            continue

        i = 0
        while True:
            try:
                fig = select_df.iloc[:, i:].T.plot(
                    figsize=ASPECT_RATIO,
                    xlabel="Date",
                    ylabel=description,
                    title=f"{description} in {zips}",
                )
                fig.get_figure().savefig(f"./viz/{url.split('/')[-1]}.png")
                fig.get_figure().clf()
                print(f"fig saved to: ./viz/{url.split('/')[-1]}.png")
                break
            except:
                i += 1
                if i > 10:
                    break
# Out:
# fig saved to: ./viz/Zip_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Zip_zhvi_uc_sfrcondo_tier_0.33_0.67_month.csv.png
# fig saved to: ./viz/Zip_zhvi_uc_sfrcondo_tier_0.67_1.0_sm_sa_month.csv.png
# fig saved to: ./viz/Zip_zhvi_uc_sfrcondo_tier_0.0_0.33_sm_sa_month.csv.png
# fig saved to: ./viz/Zip_zhvi_uc_sfr_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Zip_zhvi_uc_condo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Zip_zhvi_bdrmcnt_1_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Zip_zhvi_bdrmcnt_2_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Zip_zhvi_bdrmcnt_3_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Zip_zhvi_bdrmcnt_4_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Zip_zhvi_bdrmcnt_5_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Zip_zhvf_growth_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Zip_zhvf_growth_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Zip_zori_uc_sfrcondomfr_sm_month.csv.png
# fig saved to: ./viz/Zip_zori_uc_sfrcondomfr_sm_sa_month.csv.png
# fig saved to: ./viz/Zip_invt_fs_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Zip_invt_fs_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Zip_invt_fs_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/Zip_invt_fs_uc_sfr_sm_week.csv.png
# fig saved to: ./viz/Zip_invt_fs_uc_sfrcondo_month.csv.png
# /home/user/.local/lib/python3.14/site-packages/pandas/plotting/_matplotlib/core.py:599: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=self.figsize)
# fig saved to: ./viz/Zip_invt_fs_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Zip_invt_fs_uc_sfr_month.csv.png
# fig saved to: ./viz/Zip_invt_fs_uc_sfr_week.csv.png
# fig saved to: ./viz/Zip_new_listings_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Zip_new_listings_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Zip_new_listings_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Zip_new_listings_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Zip_new_pending_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Zip_new_pending_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Zip_mlp_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Zip_mlp_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Zip_mlp_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/Zip_mlp_uc_sfr_sm_week.csv.png
# fig saved to: ./viz/Zip_mlp_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Zip_mlp_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Zip_mlp_uc_sfr_month.csv.png
# fig saved to: ./viz/Zip_mlp_uc_sfr_week.csv.png
# fig saved to: ./viz/Zip_median_sale_price_uc_sfrcondo_sm_sa_month.csv.png
# fig saved to: ./viz/Zip_median_sale_price_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Zip_median_sale_price_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Zip_median_sale_price_uc_sfr_sm_sa_month.csv.png
# fig saved to: ./viz/Zip_median_sale_price_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/Zip_median_sale_price_uc_sfr_month.csv.png
# fig saved to: ./viz/Zip_mean_sale_to_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Zip_mean_sale_to_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Zip_median_sale_to_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Zip_median_sale_to_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Zip_pct_sold_above_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Zip_pct_sold_above_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Zip_pct_sold_below_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Zip_pct_sold_below_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Zip_mean_sale_price_uc_sfrcondo_sm_sa_month.csv.png
# fig saved to: ./viz/Zip_mean_sale_price_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Zip_mean_sale_price_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Zip_total_transaction_value_uc_sfrcondo_sm_sa_month.csv.png
# fig saved to: ./viz/Zip_total_transaction_value_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Zip_total_transaction_value_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Zip_total_transaction_value_uc_sfr_sm_sa_month.csv.png
# fig saved to: ./viz/Zip_total_transaction_value_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/Zip_total_transaction_value_uc_sfr_month.csv.png
# fig saved to: ./viz/Zip_mean_doz_pending_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Zip_mean_doz_pending_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Zip_med_doz_pending_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Zip_med_doz_pending_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Zip_mean_days_to_close_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Zip_mean_days_to_close_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Zip_median_days_to_close_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Zip_median_days_to_close_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Zip_perc_listings_price_cut_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/Zip_perc_listings_price_cut_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/Zip_perc_listings_price_cut_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/Zip_perc_listings_price_cut_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/Zip_perc_listings_price_cut_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/Zip_perc_listings_price_cut_uc_sfr_sm_week.csv.png
# fig saved to: ./viz/Zip_perc_listings_price_cut_uc_sfr_month.csv.png
# fig saved to: ./viz/Zip_perc_listings_price_cut_uc_sfr_week.csv.png
# fig saved to: ./viz/Zip_market_temp_index_uc_sfrcondo_month.csv.png

# %%
# !pip install pgeocode

# %%
import pgeocode


def zip_to_city(zip_code, country_code="US"):
    # Initialize a Nominatim object for the specified country
    nomi = pgeocode.Nominatim(country_code)

    # Get location data for the zip code
    location = nomi.query_postal_code(zip_code)

    # Extract the city name
    city = location.place_name

    return city


for zip_code in zips:
    city_name = zip_to_city(zip_code)
    print(f"The city for zip code {zip_code} is {city_name}")
# Out:
# The city for zip code 48374 is Novi
# The city for zip code 48375 is Novi
# The city for zip code 48167 is Northville
# The city for zip code 48335 is Farmington
# The city for zip code 48336 is Farmington
# The city for zip code 48167 is Northville
# The city for zip code 48152 is Livonia
# The city for zip code 48240 is Redford
# The city for zip code 48168 is Northville
# The city for zip code 48154 is Livonia
# The city for zip code 48239 is Redford
# The city for zip code 48170 is Plymouth
# The city for zip code 48150 is Livonia

# %% [markdown]
# # City Viz

# %%
cities = [
    "Plymouth",
    "Farmington",
    "Farmington Hills",
    "Novi",
    "Livonia",
    "Northville",
    "Redford",
    "Franklin",
    "Wixom",
    "Commerce",
]

for description, url in doc_urls.items():
    url = url.replace("Metro", "City")
    if url.split("/")[-1].startswith("City"):
        path = "./data/" + url
        # print(f'starting viz for path {path}')
        try:
            df = pd.read_csv(path)
            df = df[df.StateName == "MI"]
        except Exception as e:
            # print(f'failed to read {path}: {e}')
            continue
        try:
            select_df = df[df.RegionName.isin(cities)].set_index("RegionName")
        except AttributeError as e:
            # print(f'failed to select {path}: {e}')
            continue

        i = 0
        while True:
            try:
                fig = select_df.iloc[:, i:].T.plot(
                    figsize=ASPECT_RATIO,
                    xlabel="Date",
                    ylabel=description,
                    title=f"{description} in {cities}",
                )
                fig.get_figure().savefig(f"./viz/{url.split('/')[-1]}.png")
                fig.get_figure().clf()
                print(f"fig saved to: ./viz/{url.split('/')[-1]}.png")
                break
            except:
                i += 1
                if i > 20:
                    break
# Out:
# fig saved to: ./viz/City_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/City_zhvi_uc_sfrcondo_tier_0.33_0.67_month.csv.png
# fig saved to: ./viz/City_zhvi_uc_sfrcondo_tier_0.67_1.0_sm_sa_month.csv.png
# fig saved to: ./viz/City_zhvi_uc_sfrcondo_tier_0.0_0.33_sm_sa_month.csv.png
# fig saved to: ./viz/City_zhvi_uc_sfr_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/City_zhvi_uc_condo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/City_zhvi_bdrmcnt_1_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/City_zhvi_bdrmcnt_2_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/City_zhvi_bdrmcnt_3_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/City_zhvi_bdrmcnt_4_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/City_zhvi_bdrmcnt_5_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/City_zori_uc_sfrcondomfr_sm_month.csv.png
# fig saved to: ./viz/City_zori_uc_sfrcondomfr_sm_sa_month.csv.png
# fig saved to: ./viz/City_invt_fs_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_invt_fs_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/City_invt_fs_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_invt_fs_uc_sfr_month.csv.png
# fig saved to: ./viz/City_new_listings_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_new_listings_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_new_pending_uc_sfrcondo_month.csv.png
# /home/user/.local/lib/python3.14/site-packages/pandas/plotting/_matplotlib/core.py:599: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=self.figsize)
# fig saved to: ./viz/City_new_pending_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_mlp_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_mlp_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/City_mlp_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_mlp_uc_sfr_month.csv.png
# fig saved to: ./viz/City_median_sale_price_uc_sfrcondo_sm_sa_month.csv.png
# fig saved to: ./viz/City_median_sale_price_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_median_sale_price_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_median_sale_price_uc_sfr_sm_sa_month.csv.png
# fig saved to: ./viz/City_median_sale_price_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/City_median_sale_price_uc_sfr_month.csv.png
# fig saved to: ./viz/City_mean_sale_to_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_mean_sale_to_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_median_sale_to_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_median_sale_to_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_pct_sold_above_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_pct_sold_above_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_pct_sold_below_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_pct_sold_below_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_mean_sale_price_uc_sfrcondo_sm_sa_month.csv.png
# fig saved to: ./viz/City_mean_sale_price_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_mean_sale_price_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_total_transaction_value_uc_sfrcondo_sm_sa_month.csv.png
# fig saved to: ./viz/City_total_transaction_value_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_total_transaction_value_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_total_transaction_value_uc_sfr_sm_sa_month.csv.png
# fig saved to: ./viz/City_total_transaction_value_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/City_total_transaction_value_uc_sfr_month.csv.png
# fig saved to: ./viz/City_mean_doz_pending_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_mean_doz_pending_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_med_doz_pending_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_med_doz_pending_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_mean_days_to_close_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_mean_days_to_close_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_median_days_to_close_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_median_days_to_close_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_perc_listings_price_cut_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_perc_listings_price_cut_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_perc_listings_price_cut_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/City_perc_listings_price_cut_uc_sfr_month.csv.png
# fig saved to: ./viz/City_mean_listings_price_cut_amt_uc_sfr_month.csv.png
# fig saved to: ./viz/City_mean_listings_price_cut_amt_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/City_mean_listings_price_cut_amt_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_mean_listings_price_cut_amt_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_mean_listings_price_cut_perc_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_mean_listings_price_cut_perc_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_med_listings_price_cut_amt_uc_sfr_month.csv.png
# fig saved to: ./viz/City_med_listings_price_cut_amt_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/City_med_listings_price_cut_amt_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_med_listings_price_cut_amt_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_med_listings_price_cut_perc_uc_sfr_month.csv.png
# fig saved to: ./viz/City_med_listings_price_cut_perc_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/City_med_listings_price_cut_perc_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/City_med_listings_price_cut_perc_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/City_market_temp_index_uc_sfrcondo_month.csv.png

# %% [markdown]
# # County Viz

# %%
counties = [
    "Oakland County",
    "Wayne County",
    "Livingston County",
    "Washtenaw County",
    "Genesee County",
]

for description, url in doc_urls.items():
    url = url.replace("Metro", "County")
    if url.split("/")[-1].startswith("County"):
        path = "./data/" + url
        # print(f'starting viz for path {path}')
        try:
            df = pd.read_csv(path)
            df = df[df.StateName == "MI"]
        except Exception as e:
            # print(f'failed to read {path}: {e}')
            continue
        try:
            select_df = df[df.RegionName.isin(counties)].set_index("RegionName")
            select_df = select_df.drop(columns=["StateCodeFIPS", "MunicipalCodeFIPS"])
        except AttributeError as e:
            # print(f'failed to select {path}: {e}')
            continue

        i = 0
        while True:
            try:
                fig = select_df.iloc[:, i:].T.plot(
                    figsize=ASPECT_RATIO,
                    xlabel="Date",
                    ylabel=description,
                    title=f"{description} in {counties}",
                )
                fig.get_figure().savefig(f"./viz/{url.split('/')[-1]}.png")
                fig.get_figure().clf()
                print(f"fig saved to: ./viz/{url.split('/')[-1]}.png")
                break
            except:
                i += 1
                if i > 20:
                    break
# Out:
# fig saved to: ./viz/County_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/County_zhvi_uc_sfrcondo_tier_0.33_0.67_month.csv.png
# fig saved to: ./viz/County_zhvi_uc_sfrcondo_tier_0.67_1.0_sm_sa_month.csv.png
# fig saved to: ./viz/County_zhvi_uc_sfrcondo_tier_0.0_0.33_sm_sa_month.csv.png
# fig saved to: ./viz/County_zhvi_uc_sfr_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/County_zhvi_uc_condo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/County_zhvi_bdrmcnt_1_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/County_zhvi_bdrmcnt_2_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/County_zhvi_bdrmcnt_3_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/County_zhvi_bdrmcnt_4_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/County_zhvi_bdrmcnt_5_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/County_zori_uc_sfrcondomfr_sm_month.csv.png
# fig saved to: ./viz/County_zori_uc_sfrcondomfr_sm_sa_month.csv.png
# fig saved to: ./viz/County_invt_fs_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_invt_fs_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/County_invt_fs_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/County_invt_fs_uc_sfr_sm_week.csv.png
# fig saved to: ./viz/County_invt_fs_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_invt_fs_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/County_invt_fs_uc_sfr_month.csv.png
# /home/user/.local/lib/python3.14/site-packages/pandas/plotting/_matplotlib/core.py:599: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=self.figsize)
# fig saved to: ./viz/County_invt_fs_uc_sfr_week.csv.png
# fig saved to: ./viz/County_new_listings_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_new_listings_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/County_new_listings_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_new_listings_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/County_new_pending_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_new_pending_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_mlp_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_mlp_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/County_mlp_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/County_mlp_uc_sfr_sm_week.csv.png
# fig saved to: ./viz/County_mlp_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_mlp_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/County_mlp_uc_sfr_month.csv.png
# fig saved to: ./viz/County_mlp_uc_sfr_week.csv.png
# fig saved to: ./viz/County_median_sale_price_uc_sfrcondo_sm_sa_month.csv.png
# fig saved to: ./viz/County_median_sale_price_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_median_sale_price_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_median_sale_price_uc_sfr_sm_sa_month.csv.png
# fig saved to: ./viz/County_median_sale_price_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/County_median_sale_price_uc_sfr_month.csv.png
# fig saved to: ./viz/County_mean_sale_to_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_mean_sale_to_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_median_sale_to_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_median_sale_to_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_pct_sold_above_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_pct_sold_above_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_pct_sold_below_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_pct_sold_below_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_mean_sale_price_uc_sfrcondo_sm_sa_month.csv.png
# fig saved to: ./viz/County_mean_sale_price_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_mean_sale_price_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_total_transaction_value_uc_sfrcondo_sm_sa_month.csv.png
# fig saved to: ./viz/County_total_transaction_value_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_total_transaction_value_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_total_transaction_value_uc_sfr_sm_sa_month.csv.png
# fig saved to: ./viz/County_total_transaction_value_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/County_total_transaction_value_uc_sfr_month.csv.png
# fig saved to: ./viz/County_mean_doz_pending_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_mean_doz_pending_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_med_doz_pending_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_med_doz_pending_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_mean_days_to_close_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_mean_days_to_close_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_median_days_to_close_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_median_days_to_close_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_perc_listings_price_cut_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_perc_listings_price_cut_uc_sfrcondo_sm_week.csv.png
# fig saved to: ./viz/County_perc_listings_price_cut_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_perc_listings_price_cut_uc_sfrcondo_week.csv.png
# fig saved to: ./viz/County_perc_listings_price_cut_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/County_perc_listings_price_cut_uc_sfr_sm_week.csv.png
# fig saved to: ./viz/County_perc_listings_price_cut_uc_sfr_month.csv.png
# fig saved to: ./viz/County_perc_listings_price_cut_uc_sfr_week.csv.png
# fig saved to: ./viz/County_mean_listings_price_cut_amt_uc_sfr_month.csv.png
# fig saved to: ./viz/County_mean_listings_price_cut_amt_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/County_mean_listings_price_cut_amt_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_mean_listings_price_cut_amt_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_mean_listings_price_cut_perc_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_mean_listings_price_cut_perc_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_med_listings_price_cut_amt_uc_sfr_month.csv.png
# fig saved to: ./viz/County_med_listings_price_cut_amt_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/County_med_listings_price_cut_amt_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_med_listings_price_cut_amt_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_med_listings_price_cut_perc_uc_sfr_month.csv.png
# fig saved to: ./viz/County_med_listings_price_cut_perc_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/County_med_listings_price_cut_perc_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/County_med_listings_price_cut_perc_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/County_market_temp_index_uc_sfrcondo_month.csv.png

# %% [markdown]
# # State Viz

# %%
states = ["Michigan", "Oregon", "Washington", "California", "Colorado", "Utah"]

for description, url in doc_urls.items():
    url = url.replace("Metro", "State")
    if url.split("/")[-1].startswith("State"):
        path = "./data/" + url
        # print(f'starting viz for path {path}')
        try:
            df = pd.read_csv(path)
        except Exception as e:
            # print(f'failed to read {path}: {e}')
            continue
        try:
            select_df = df[df.RegionName.isin(states)].set_index("RegionName")
            select_df = select_df.drop(columns=["StateName"])
        except AttributeError as e:
            # print(f'failed to select {path}: {e}')
            continue

        i = 0
        while True:
            try:
                fig = select_df.iloc[:, i:].T.plot(
                    figsize=ASPECT_RATIO,
                    xlabel="Date",
                    ylabel=description,
                    title=f"{description} in {states}",
                )
                fig.get_figure().savefig(f"./viz/{url.split('/')[-1]}.png")
                fig.get_figure().clf()
                print(f"fig saved to: ./viz/{url.split('/')[-1]}.png")
                break
            except:
                i += 1
                if i > 20:
                    break
# Out:
# fig saved to: ./viz/State_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/State_zhvi_uc_sfrcondo_tier_0.33_0.67_month.csv.png
# fig saved to: ./viz/State_zhvi_uc_sfrcondo_tier_0.67_1.0_sm_sa_month.csv.png
# fig saved to: ./viz/State_zhvi_uc_sfrcondo_tier_0.0_0.33_sm_sa_month.csv.png
# fig saved to: ./viz/State_zhvi_uc_sfr_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/State_zhvi_uc_condo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/State_zhvi_bdrmcnt_1_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/State_zhvi_bdrmcnt_2_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/State_zhvi_bdrmcnt_3_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/State_zhvi_bdrmcnt_4_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/State_zhvi_bdrmcnt_5_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/State_invt_fs_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_invt_fs_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/State_invt_fs_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_invt_fs_uc_sfr_month.csv.png
# fig saved to: ./viz/State_new_listings_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_new_listings_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_new_pending_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_new_pending_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_mlp_uc_sfrcondo_sm_month.csv.png
# /home/user/.local/lib/python3.14/site-packages/pandas/plotting/_matplotlib/core.py:599: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=self.figsize)
# fig saved to: ./viz/State_mlp_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/State_mlp_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_mlp_uc_sfr_month.csv.png
# fig saved to: ./viz/State_median_sale_price_uc_sfrcondo_sm_sa_month.csv.png
# fig saved to: ./viz/State_median_sale_price_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_median_sale_price_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_median_sale_price_uc_sfr_sm_sa_month.csv.png
# fig saved to: ./viz/State_median_sale_price_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/State_median_sale_price_uc_sfr_month.csv.png
# fig saved to: ./viz/State_mean_sale_to_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_mean_sale_to_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_median_sale_to_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_median_sale_to_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_pct_sold_above_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_pct_sold_above_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_pct_sold_below_list_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_pct_sold_below_list_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_mean_sale_price_uc_sfrcondo_sm_sa_month.csv.png
# fig saved to: ./viz/State_mean_sale_price_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_mean_sale_price_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_total_transaction_value_uc_sfrcondo_sm_sa_month.csv.png
# fig saved to: ./viz/State_total_transaction_value_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_total_transaction_value_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_total_transaction_value_uc_sfr_sm_sa_month.csv.png
# fig saved to: ./viz/State_total_transaction_value_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/State_total_transaction_value_uc_sfr_month.csv.png
# fig saved to: ./viz/State_mean_doz_pending_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_mean_doz_pending_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_med_doz_pending_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_med_doz_pending_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_mean_days_to_close_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_mean_days_to_close_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_median_days_to_close_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_median_days_to_close_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_perc_listings_price_cut_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_perc_listings_price_cut_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_perc_listings_price_cut_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/State_perc_listings_price_cut_uc_sfr_month.csv.png
# fig saved to: ./viz/State_mean_listings_price_cut_amt_uc_sfr_month.csv.png
# fig saved to: ./viz/State_mean_listings_price_cut_amt_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/State_mean_listings_price_cut_amt_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_mean_listings_price_cut_amt_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_mean_listings_price_cut_perc_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_mean_listings_price_cut_perc_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_med_listings_price_cut_amt_uc_sfr_month.csv.png
# fig saved to: ./viz/State_med_listings_price_cut_amt_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/State_med_listings_price_cut_amt_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_med_listings_price_cut_amt_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_med_listings_price_cut_perc_uc_sfr_month.csv.png
# fig saved to: ./viz/State_med_listings_price_cut_perc_uc_sfr_sm_month.csv.png
# fig saved to: ./viz/State_med_listings_price_cut_perc_uc_sfrcondo_month.csv.png
# fig saved to: ./viz/State_med_listings_price_cut_perc_uc_sfrcondo_sm_month.csv.png
# fig saved to: ./viz/State_market_temp_index_uc_sfrcondo_month.csv.png

# %% [markdown]
# # Neighborhood Viz

# %%
hoods = [
    "SMB Estates",
    "Clements Circle",
    "Coventry Gardens",
    "Woodbury Park",
    "Willow Woods",
]

for description, url in doc_urls.items():
    url = url.replace("Metro", "Neighborhood")
    if url.split("/")[-1].startswith("Neighborhood"):
        path = "./data/" + url
        # print(f'starting viz for path {path}')
        try:
            df = pd.read_csv(path)
            df = df[df.StateName == "MI"]
        except Exception as e:
            # print(f'failed to read {path}: {e}')
            continue
        try:
            select_df = df[df.RegionName.isin(hoods)].set_index("RegionName")
        except AttributeError as e:
            # print(f'failed to select {path}: {e}')
            continue

        i = 0
        while True:
            try:
                fig = select_df.iloc[:, i:].T.plot(
                    figsize=ASPECT_RATIO,
                    xlabel="Date",
                    ylabel=description,
                    title=f"{description} in {hoods}",
                )
                fig.get_figure().savefig(f"./viz/{url.split('/')[-1]}.png")
                fig.get_figure().clf()
                print(f"fig saved to: ./viz/{url.split('/')[-1]}.png")
                break
            except:
                i += 1
                if i > 20:
                    break
# Out:
# fig saved to: ./viz/Neighborhood_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Neighborhood_zhvi_uc_sfrcondo_tier_0.33_0.67_month.csv.png
# fig saved to: ./viz/Neighborhood_zhvi_uc_sfrcondo_tier_0.67_1.0_sm_sa_month.csv.png
# fig saved to: ./viz/Neighborhood_zhvi_uc_sfrcondo_tier_0.0_0.33_sm_sa_month.csv.png
# fig saved to: ./viz/Neighborhood_zhvi_uc_sfr_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Neighborhood_zhvi_bdrmcnt_3_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Neighborhood_zhvi_bdrmcnt_4_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv.png
# fig saved to: ./viz/Neighborhood_market_temp_index_uc_sfrcondo_month.csv.png
